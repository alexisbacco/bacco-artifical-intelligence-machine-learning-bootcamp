# %% [markdown]
# # Pandas Practice
#
# This notebook is dedicated to practicing different tasks with pandas. These example exercises were practiced in my data science bootcamp. All content within this example is fake data only!
#
# The different tasks will be detailed by comments or text.
#
# For my own assistance - For further reference and resources, it's advised to check out the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/).

# %%
# Import pandas
import pandas as pd

# %%
# Create a series of three different colors
colors = pd.Series(["red", "green", "blue"])

# %%
# View the series of different colours
colors
# Out:
# 0      red
# 1    green
# 2     blue
# dtype: object

# %%
# Create a series of three different car types and view it
car_types = pd.Series(["Honda", "Toyota", "Kia"])
car_types
# Out:
# 0     Honda
# 1    Toyota
# 2       Kia
# dtype: object

# %%
# Combine the Series of cars and colours into a DataFrame
df = pd.DataFrame({"Color": colors, "Car Type": car_types})
df
# Out:
#    Color Car Type
# 0    red    Honda
# 1  green   Toyota
# 2   blue      Kia

# %%
# Import "../data/car-sales.csv" and turn it into a DataFrame
car_sales = pd.read_csv("car-sales.csv")
df = pd.DataFrame(car_sales)
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Describe your current car sales DataFrame using describe()
car_sales = df.describe()
car_sales
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
# Get information about your DataFrame using info()
df.info
# Out:
# <bound method DataFrame.info of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %%
# Create a Series of different numbers and find the mean of them
numbers = pd.Series([5, 10, 15, 20, 25])
mean_value = numbers.mean()
mean_value
# Out:
# np.float64(15.0)

# %%
# Create a Series of different numbers and find the sum of them
numbers = pd.Series([10, 20, 30, 40, 50])
sum_value = numbers.sum()
sum_value
# Out:
# np.int64(150)

# %%
# List out all the column names of the car sales DataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales.columns.tolist()
# Out:
# ['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price']

# %%
# Find the length of the car sales DataFrame
length = len(car_sales)
print("Number of rows in car_sales:", length)
# Out:
# Number of rows in car_sales: 10

# %%
# Show the first 5 rows of the car sales DataFrame
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# Show the first 7 rows of the car sales DataFrame
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
# Show the bottom 5 rows of the car sales DataFrame
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# Use .loc to select the row at index 3 of the car sales DataFrame
row_3 = car_sales.loc[3]
row_3
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Use .iloc to select the row at position 3 of the car sales DataFrame
position_3 = car_sales.iloc[3]
position_3
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %% [markdown]
# Trick question - they are the same answer!
# Check the pandas documentation for [.loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html) and [.iloc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html)

# %%
# Select the "Odometer (KM)" column from the car sales DataFrame
odometer = car_sales["Odometer (KM)"]
odometer
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# Find the mean of the "Odometer (KM)" column in the car sales DataFrame
mean = odometer.mean()
mean
# Out:
# np.float64(78601.4)

# %%
# Select the rows with over 100,000 kilometers on the Odometer
high_mileage = car_sales[car_sales["Odometer (KM)"] > 100000]
high_mileage
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
# Create a crosstab of the Make and Doors columns
crosstab_result = pd.crosstab(car_sales["Make"], car_sales["Doors"])
crosstab_result
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Group columns of the car sales DataFrame by the Make column and find the average
average = car_sales.groupby("Make").mean(numeric_only=True)
average
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# Import Matplotlib and create a plot
# Don't forget to use %matplotlib inline
import matplotlib.pyplot as plt
car_sales = pd.read_csv("car-sales.csv")

#Plot the Odometer Column
plt.figure(figsize=(10, 5))
plt.plot(car_sales["Odometer (KM)"], marker='o', linestyle='-', color='blue')
plt.title("Odometer Readings")
plt.xlabel("Index")
plt.ylabel("Odometer (KM)")
plt.grid(True)
plt.show()

# %%
# Create a histogram of the Odometer column using hist()
car_sales["Odometer (KM)"].hist(bins=10, color='skyblue', edgecolor='black')

plt.title("Distribution of Odometer Readings")
plt.xlabel("Odometer (KM)")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# Remove the punctuation from price column
car_sales["Price"] = car_sales["Price"].astype(str).str.replace(r'[\$,]', '', regex=True).astype(float)
print(car_sales["Price"])
# Out:
# 0     4000.0
# 1     5000.0
# 2     7000.0
# 3    22000.0
# 4     3500.0
# 5     4500.0
# 6     7500.0
# 7     7000.0
# 8     6250.0
# 9     9700.0
# Name: Price, dtype: float64

# %%
# Remove the two extra zeros at the end of the price column
car_sales["Price"] = car_sales["Price"].astype(int)
print(car_sales["Price"])
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int64

# %%
# Check the changes to the Price column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# Lower the strings of the Make column
car_sales["Make"] = car_sales["Make"].str.lower()
print(car_sales["Make"])
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
# Import the car sales DataFrame with missing data ("../data/car-sales-missing-data.csv")
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# Check out the new DataFrame
df = pd.DataFrame(car_sales_missing)
df
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# Fill the Odometer column missing values with the mean of the column inplace
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
print(car_sales_missing["Odometer"])
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
# View the car sales missing DataFrame and verify the changes
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
# Remove the rest of the missing data (remove any data with NaN left)
car_sales_missing.dropna(inplace=True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
# Create a "Seats" column where every row has a value of 5
car_sales_missing["Seats"] = 5
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000      5
# 1   Honda    Red   87899.000000    4.0   $5,000      5
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5
# 3     BMW  Black   11179.000000    5.0  $22,000      5
# 4  Nissan  White  213095.000000    4.0   $3,500      5
# 5  Toyota  Green   92302.666667    4.0   $4,500      5

# %%
# Create a column called "Engine Size" with random values between 1.3 and 4.5
import pandas as pd
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
import numpy as np
engine_size = np.random.uniform(1.3, 4.5, size=len(car_sales_missing))
car_sales_missing["Engine Size"] = np.round(engine_size, 1)
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price  Engine Size
# 0  Toyota  White  150043.0    4.0   $4,000          2.1
# 1   Honda    Red   87899.0    4.0   $5,000          3.2
# 2  Toyota   Blue       NaN    3.0   $7,000          1.3
# 3     BMW  Black   11179.0    5.0  $22,000          2.5
# 4  Nissan  White  213095.0    4.0   $3,500          1.5
# 5  Toyota  Green       NaN    4.0   $4,500          3.5
# 6   Honda    NaN       NaN    4.0   $7,500          1.9
# 7   Honda   Blue       NaN    4.0      NaN          4.4
# 8  Toyota  White   60000.0    NaN      NaN          3.9
# 9     NaN  White   31600.0    4.0   $9,700          3.1

# %%
# Create a column which represents the price of a car per kilometer
# Then view the DataFrame
car_sales_missing["Price"] = car_sales_missing["Price"].astype(str).str.replace(r'[\$,]', '', regex=True).astype(float)
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
car_sales_missing["Price per KM"] = car_sales["Price"] / car_sales["Odometer (KM)"]
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Engine Size  Price per KM
# 0  Toyota  White  150043.000000    4.0   4000.0          2.1      0.026659
# 1   Honda    Red   87899.000000    4.0   5000.0          3.2      0.056883
# 2  Toyota   Blue   92302.666667    3.0   7000.0          1.3      0.215060
# 3     BMW  Black   11179.000000    5.0  22000.0          2.5      1.967976
# 4  Nissan  White  213095.000000    4.0   3500.0          1.5      0.016425
# 5  Toyota  Green   92302.666667    4.0   4500.0          3.5      0.045357
# 6   Honda    NaN   92302.666667    4.0   7500.0          1.9      0.164121
# 7   Honda   Blue   92302.666667    4.0      NaN          4.4      0.127882
# 8  Toyota  White   60000.000000    NaN      NaN          3.9      0.104167
# 9     NaN  White   31600.000000    4.0   9700.0          3.1      0.306962

# %%
# Shuffle the DataFrame using sample() with the frac parameter set to 1
# Save the the shuffled DataFrame to a new variable
car_sales_shuffled = car_sales_missing.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour       Odometer  Doors    Price  Engine Size
# 2  Toyota   Blue   92302.666667    3.0   7000.0          1.3
# 5  Toyota  Green   92302.666667    4.0   4500.0          3.5
# 6   Honda    NaN   92302.666667    4.0   7500.0          1.9
# 9     NaN  White   31600.000000    4.0   9700.0          3.1
# 3     BMW  Black   11179.000000    5.0  22000.0          2.5
# 1   Honda    Red   87899.000000    4.0   5000.0          3.2
# 4  Nissan  White  213095.000000    4.0   3500.0          1.5
# 7   Honda   Blue   92302.666667    4.0      NaN          4.4
# 8  Toyota  White   60000.000000    NaN      NaN          3.9
# 0  Toyota  White  150043.000000    4.0   4000.0          2.1

# %% [markdown]
# Notice how the index numbers get moved around. The [`sample()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html) function is a great way to get random samples from your DataFrame. It's also another great way to shuffle the rows by setting `frac=1`.

# %%
# Reset the indexes of the shuffled DataFrame
car_sales_shuffled = car_sales_shuffled.reset_index(drop=True)
car_sales_shuffled
# Out:
#      Make Colour       Odometer  Doors    Price  Engine Size
# 0  Toyota   Blue   92302.666667    3.0   7000.0          1.3
# 1  Toyota  Green   92302.666667    4.0   4500.0          3.5
# 2   Honda    NaN   92302.666667    4.0   7500.0          1.9
# 3     NaN  White   31600.000000    4.0   9700.0          3.1
# 4     BMW  Black   11179.000000    5.0  22000.0          2.5
# 5   Honda    Red   87899.000000    4.0   5000.0          3.2
# 6  Nissan  White  213095.000000    4.0   3500.0          1.5
# 7   Honda   Blue   92302.666667    4.0      NaN          4.4
# 8  Toyota  White   60000.000000    NaN      NaN          3.9
# 9  Toyota  White  150043.000000    4.0   4000.0          2.1

# %%
# Change the Odometer values from kilometers to miles using a Lambda function
# Then view the DataFrame
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].apply(lambda km: round(km * 0.621371, 1))
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price  Engine Size
# 0  Toyota  White   57931.9    4.0   4000.0          2.1
# 1   Honda    Red   33938.0    4.0   5000.0          3.2
# 2  Toyota   Blue   35638.2    3.0   7000.0          1.3
# 3     BMW  Black    4316.2    5.0  22000.0          2.5
# 4  Nissan  White   82276.4    4.0   3500.0          1.5
# 5  Toyota  Green   35638.2    4.0   4500.0          3.5
# 6   Honda    NaN   35638.2    4.0   7500.0          1.9
# 7   Honda   Blue   35638.2    4.0      NaN          4.4
# 8  Toyota  White   23166.1    NaN      NaN          3.9
# 9     NaN  White   12200.8    4.0   9700.0          3.1

# %%
# Change the title of the Odometer (KM) to represent miles instead of kilometers
car_sales_missing.rename(columns={"Odometer": "Odometer (Miles)"}, inplace=True)
car_sales_missing
# Out:
#      Make Colour  Odometer (Miles)  Doors    Price  Engine Size
# 0  Toyota  White           57931.9    4.0   4000.0          2.1
# 1   Honda    Red           33938.0    4.0   5000.0          3.2
# 2  Toyota   Blue           35638.2    3.0   7000.0          1.3
# 3     BMW  Black            4316.2    5.0  22000.0          2.5
# 4  Nissan  White           82276.4    4.0   3500.0          1.5
# 5  Toyota  Green           35638.2    4.0   4500.0          3.5
# 6   Honda    NaN           35638.2    4.0   7500.0          1.9
# 7   Honda   Blue           35638.2    4.0      NaN          4.4
# 8  Toyota  White           23166.1    NaN      NaN          3.9
# 9     NaN  White           12200.8    4.0   9700.0          3.1
